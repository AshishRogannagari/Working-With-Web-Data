# %% [markdown]
# # **`Working With Web Data`**

# %% [markdown]
# # <center><u>Author</u></center>
# # <center><u>Ashish Rogannagari</u></center>

# %% [markdown]
# ![py.PNG](data:image/png;base64,...)

# %% [markdown]
# ## <center><u>`XML PARSING`</u></center>

# %% [markdown]
# `XML (eXtensible Markup Language):`
# XML is a markup language that defines a set of rules for encoding documents in a format that is both human-readable and machine-readable. It's commonly used to structure and store data in a hierarchical and platform-independent way.
#
# `BeautifulSoup:`
# BeautifulSoup is a Python library for pulling data out of HTML and XML files.

# %%
from src.XMLParsing import SitemapParser

# %%
website_url = 'https://www.seoptimer.com'

    # Create an instance of the SitemapParser class
parser = SitemapParser(website_url)

    # Get the robots.txt file and extract sitemaps
parser.get_robots_txt()

    # Parse the contents of each sitemap into a DataFrame and get the result
result = parser.parse_sitemaps()

    # Display the output in a nicely formatted table
parser.display_output(result)
# Out:
# Sitemap: https://www.seoptimer.com/sitemap_index.xml
# ╒════╤════════════════════════════════════════════════════════╕
# │    │ URL                                                    │
# ╞════╪════════════════════════════════════════════════════════╡
# │  0 │ https://www.seoptimer.com/sitemap/sitemap_user.xml     │
# ├────┼────────────────────────────────────────────────────────┤
# │  1 │ https://www.seoptimer.com/sitemap/sitemap_tools.xml    │
# ├────┼────────────────────────────────────────────────────────┤
# │  2 │ https://www.seoptimer.com/blog/post-sitemap.xml        │
# ├────┼────────────────────────────────────────────────────────┤
# │  3 │ https://www.seoptimer.com/blog/category-sitemap.xml    │
# ├────┼────────────────────────────────────────────────────────┤
# │  4 │ https://www.seoptimer.com/fr/blog/post-sitemap.xml     │
# ├────┼────────────────────────────────────────────────────────┤
# │  5 │ https://www.seoptimer.com/fr/blog/category-sitemap.xml │
# ...

# %% [markdown]
# The website's sitemaps were obtained through xml parsing on the provided URL.

# %% [markdown]
# The dataset obtained from the provided code comes from parsing the XML sitemap of the website 'https://www.seoptimer.com'. XML sitemaps serve as a structured way for webmasters to communicate with search engines, providing information about accessible pages for crawling. In this instance, the dataset is expected to contain URLs and potentially other relevant details, such as the last modified dates, pertaining to various pages or content on the 'https://www.seoptimer.com' website.

# %% [markdown]
# This information can be invaluable for SEO (Search Engine Optimization) efforts, as it allows webmasters to understand the structure of their website, identify key pages, and provide search engines with up-to-date information about the content available for indexing. The dataset, once processed, can be used for further analysis and optimization strategies to enhance the website's visibility in search engine results.

# %% [markdown]
# ### `The dataset obtained from parsing the XML sitemap of 'https://www.seoptimer.com' has several potential uses:`
#
#  SEO Optimization: Informing strategies for improving site structure, internal linking, and content optimization.
#
#  Content Analysis: Understanding the website's content, identifying key pages, and detecting content gaps.
#
#  Indexing and Crawling Optimization: Prioritizing pages for search engine crawlers based on last modified dates.
#
#  Issue Identification: Finding broken links, redirects, or missing pages for website maintenance.
#
#  Performance Monitoring: Tracking changes over time to assess content updates and identify outdated sections.
#
#  Competitive Analysis: Comparing with competitors' datasets for strategic insights.
#
#  User Experience Enhancement: Improving navigation and ensuring relevant content accessibility.
#
#  Search Engine Ranking Improvement: Mapping URLs to target keywords for better search engine rankings.

# %% [markdown]
# ## <center><u>`API PARSING`</u></center>

# %% [markdown]
# #### API parsing, often referred to as consuming or interacting with an API (Application Programming Interface), involves retrieving data from a web server in a structured format (usually JSON or XML) and then parsing that data for further use. APIs allow different software applications to communicate and exchange data in a standardized manner.

# %%
from src import Api_EDA

# %% [markdown]
# API Overview:
#
# ##### The URL https://api.artic.edu/api/v1/artworks is an API endpoint provided by the Art Institute of Chicago's public API.
#
#
# API Base URL: https://api.artic.edu/api/v1.
#
# Endpoint: /artworks

# %% [markdown]
#    ## <center><u>`Web Scraping` </u></center>

# %% [markdown]
# ### Web scraping is the process of extracting data from websites. It involves fetching the web page, parsing its HTML (or XML) content, and then extracting the desired information.

# %% [markdown]
# `Importing the WebScraping.py Package.`

# %%
from src import WebScraping
from src.WebScraping import MyWikiScraper

# %% [markdown]
# #### I scraped the page using this address 'https://en.wikipedia.org/wiki/Main_Page'. As a result, it displayed the Today's Main Article on the page.

# %% [markdown]
# ### ` Web scraping provides several benefits, including:`
#
# Data Extraction: Collects information from websites for research, analysis, or business intelligence.
#
# Competitive Analysis: Monitors competitors by tracking pricing, product details, and reviews.
#
# Market Research: Gathers market data to understand trends, consumer behavior, and industry dynamics.
#
# Lead Generation: Identifies potential customers by scraping contact information.
#
# Content Aggregation: Creates comprehensive databases by aggregating content from multiple sources.

# %% [markdown]
#    ## <center><u>`API Parsing EDA` </u></center>

# %% [markdown]
# I selected API Parsing for the EDA part.

# %%
from src import Api_EDA

# %% [markdown]
# Data Summary of the API

# %%
Api_EDA.ArtworksEDA.summary()
# Out:
# Index(['id', 'api_model', 'api_link', 'is_boosted', 'title', 'alt_titles',
#        'thumbnail', 'main_reference_number', 'has_not_been_viewed_much',
#        'boost_rank', 'date_start', 'date_end', 'date_display',
#        'date_qualifier_title', 'date_qualifier_id', 'artist_display',
#        'place_of_origin', 'description', 'dimensions', 'dimensions_detail',
#        'medium_display', 'inscriptions', 'credit_line', 'catalogue_display',
#        'publication_history', 'exhibition_history', 'provenance_text',
#        'edition', 'publishing_verification_level', 'internal_department_id',
#        'fiscal_year', 'fiscal_year_deaccession', 'is_public_domain',
#        'is_zoomable', 'max_zoom_window_size', 'copyright_notice',
#        'has_multimedia_resources', 'has_educational_resources',
#        'has_advanced_imaging', 'colorfulness', 'color', 'latitude',
#        'longitude', 'latlon', 'is_on_view', 'on_loan_display', 'gallery_title',
# ...

# %% [markdown]
# The code shows the column names of the DataFrame ArtworksEDA: 'id', 'title', 'artist_display', and 'date_display'and more.

# %%
Api_EDA.ArtworksEDA.detail()
# Out:
#      id api_model                                    api_link  is_boosted  \
# 0  3816  artworks  https://api.artic.edu/api/v1/artworks/3816       False
# 1  3752  artworks  https://api.artic.edu/api/v1/artworks/3752       False
# 2  7122  artworks  https://api.artic.edu/api/v1/artworks/7122       False
# 3  6010  artworks  https://api.artic.edu/api/v1/artworks/6010       False
# 4  9505  artworks  https://api.artic.edu/api/v1/artworks/9505       False
#
#                                                title alt_titles  \
# 0                   Ornamental Panel With Two Lovers       None
# 1                          The Madonna of the Rosary       None
# 2                                         Seated Boy       None
# 3                                          Number 19       None
# 4  Two Studies of a Roma Woman and a Roma Boy in ...       None
#
#                                            thumbnail main_reference_number  \
# 0  {'lqip': '......              1956.854
# ...

# %% [markdown]
# The code shows the first five rows and columns names of the DataFrame ArtworksEDA: 'id', 'title', 'artist_display', and 'date_display'.

# %%
Api_EDA.ArtworksEDA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 98 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             12 non-null     int64
#  1   api_model                      12 non-null     object
#  2   api_link                       12 non-null     object
#  3   is_boosted                     12 non-null     bool
#  4   title                          12 non-null     object
#  5   alt_titles                     0 non-null      object
#  6   thumbnail                      12 non-null     object
#  7   main_reference_number          12 non-null     object
#  8   has_not_been_viewed_much       12 non-null     bool
#  9   boost_rank                     0 non-null      object
#  10  date_start                     12 non-null     int64
#  11  date_end                       12 non-null     int64
# ...

# %% [markdown]
# The code Api_EDA.ArtworksEDA.info() gives a summary about the DataFrame ArtworksEDA within the Api_EDA object. It includes details like data types, non-null counts, and memory usage for each column.

# %%
Api_EDA.ArtworksEDA.data_type()
# Out:
# id                               int64
# api_model                       object
# api_link                        object
# is_boosted                        bool
# title                           object
#                                  ...
# suggest_autocomplete_all        object
# source_updated_at               object
# updated_at                      object
# timestamp                       object
# suggest_autocomplete_boosted    object
# Length: 98, dtype: object

# %% [markdown]
# This code shows the data types of above rows

# %%
Api_EDA.ArtworksEDA.null_values()
# Out:
# id                              0
# api_model                       0
# api_link                        0
# is_boosted                      0
# title                           0
#                                ..
# suggest_autocomplete_all        0
# source_updated_at               0
# updated_at                      0
# timestamp                       0
# suggest_autocomplete_boosted    9
# Length: 98, dtype: int64

# %% [markdown]
# This code is used to find the null values in the data.

# %%
Api_EDA.ArtworksEDA.shape()
# Out:
# (12, 98)

# %% [markdown]
# The code Api_EDA.ArtworksEDA.shape returns the dimensions (number of rows and columns) of the DataFrame ArtworksEDA within the Api_EDA object.

# %%
Api_EDA.ArtworksEDA.describe()
# Out:
#                  id   date_start     date_end  internal_department_id  \
# count     12.000000    12.000000    12.000000               12.000000
# mean   12230.500000  1718.333333  1730.916667               66.916667
# std     6824.524632   263.132989   241.700588              108.087051
# min     3752.000000  1101.000000  1200.000000                3.000000
# 25%     6844.000000  1570.000000  1580.000000                3.000000
# 50%    11508.500000  1872.000000  1881.500000               11.000000
# 75%    15978.750000  1909.000000  1909.000000               72.000000
# max    23700.000000  1949.000000  1949.000000              246.000000
#
#        fiscal_year  max_zoom_window_size  colorfulness   latitude  longitude  \
# count     6.000000               12.0000     12.000000   2.000000   2.000000
# mean   1947.500000              426.0000     16.031167  41.879625 -87.623323
# std      15.254508              630.7208     11.789605   0.000095   0.000044
# ...

# %% [markdown]
# The code summarizes numeric data in the ArtworksEDA DataFrame within the Api_EDA object using Pandas' describe() method. It gives key statistics like mean, count, and quartiles

# %% [markdown]
#   ## <center><u>`API  visualizer` </u></center>

# %%
Api_EDA.ArtworksEDA.plot_artwork_type_distribution()

# %% [markdown]
# ### From The Above Chart we can see that `Painting` artworks are sold highly.

# %%
Api_EDA.ArtworksEDA.plot_top_artists()

# %% [markdown]
# ### Israhel van has most sold artworks from the above graph.

# %%
Api_EDA.ArtworksEDA.plot_colorfulness_distribution()

# %%
Api_EDA.ArtworksEDA.plot_department_distribution()

# %% [markdown]
# Pie chart showing  Distribution of Art work by Department
# Analysis this graph that most then are `Prints and Drawing` compare to all the category

# %%
Api_EDA.ArtworksEDA.title_wordcloud()

# %% [markdown]
# ### The word cloud above visually represents the distribution of titles in the dataset. Words that appear more frequently are displayed with larger fonts. This provides a snapshot of the most common words in the artwork titles, offering insights into the prevalent themes or subjects.

# %% [markdown]
# # `References:`

# %% [markdown]
# https://cloud.google.com/storage/docs/xml-api/overview

# %% [markdown]
# https://developers.google.com/search/docs/crawling-indexing/robots/intro

# %% [markdown]
# https://realpython.com/beautiful-soup-web-scraper-python/

# %% [markdown]
# https://realpython.com/python-xml-parser/

# %% [markdown]
# https://realpython.com/python-matplotlib-guide/

# %% [markdown]
# https://beautiful-soup-4.readthedocs.io/en/latest/

# %% [markdown]
# https://www.datacamp.com/tutorial/wordcloud-python

# %% [markdown]
# Author : `Ashish Rogannagari`
#
# https://github.com/AshishRogannagari

# %% [markdown]
# ## <center><u>`Thank you`</u></center>
